# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekkumarbehera/Machine_learning_Pratical_Implement/blob/main/Deicision_tree_reggresion_and__Cross_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as ppplt
# %matplotlib inline

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing(as_frame=True)

# %%
housing
# Out:
# {'data':        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
#  0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
#  1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
#  2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
#  3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
#  4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#  ...       ...       ...       ...        ...         ...       ...       ...
#  20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
#  20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
#  20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
#  20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
#  20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#         Longitude
# ...

# %%
#traing and Test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_bunch.py in __getattr__(self, key)
#      56         try:
# ---> 57             return self[key]
#      58         except KeyError:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_bunch.py in __getitem__(self, key)
#      41             )
# ---> 42         return super().__getitem__(key)
#      43
#
# KeyError: 'head'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_252/3447668789.py in <cell line: 0>()
# ----> 1 housing.head()
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_bunch.py in __getattr__(self, key)
#      57             return self[key]
#      58         except KeyError:
# ---> 59             raise AttributeError(key)
# ...

# %%
import seaborn as sns

# %%
fetch_california_housing
# Out:
# <function sklearn.datasets._california_housing.fetch_california_housing(*, data_home=None, download_if_missing=True, return_X_y=False, as_frame=False, n_retries=3, delay=1.0)>

# %%
#find out the indepedent and depened
X=pd.DataFrame(housing.data,columns=housing.feature_names)
y=housing.target

# %%
#Find out the Traing and Testing Data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)
