# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekkumarbehera/Machine_learning_Pratical_Implement/blob/main/EDA_Autoviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install autoviz
# Out:
# ...
#   Using cached autoviz-0.1.905-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached pyamg-5.3.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# ...
#   Using cached xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# ...
#   Using cached pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached hvplot-0.12.2-py3-none-any.whl.metadata (19 kB)
# ...
# Using cached autoviz-0.1.905-py3-none-any.whl (67 kB)
# Using cached hvplot-0.12.2-py3-none-any.whl (180 kB)
# Using cached pandas_dq-1.29-py3-none-any.whl (29 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.2.0
#     Uninstalling xgboost-3.2.0:
# ...

# %%
import seaborn as sns
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip   sex   smoker day    time   size
# 0     16.99    1.01  Female   No    Sun  Dinner    2
# 1     10.34    1.66    Male   No    Sun  Dinner    3
# 2     21.01    3.50    Male   No    Sun  Dinner    3
# 3     23.68    3.31    Male   No    Sun  Dinner    2
# 4     24.59    3.61  Female   No    Sun  Dinner    4

# %%
df.to_csv('tips.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
dfname="/content/sample_data/california_housing_train.csv"
AV = AutoViz_Class()
dft = AV.AutoViz(dfname)
# Out:
# Shape of your Data Set loaded: (17000, 9)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  9
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     9 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# ...
